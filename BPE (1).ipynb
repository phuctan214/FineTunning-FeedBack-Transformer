# %%
! pip install tokenizers
! pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.2MB 7.7MB/s
# ...
#      |████████████████████████████████| 2.0MB 7.7MB/s
# ...
#      |████████████████████████████████| 890kB 29.6MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=48db0e76ff4e40cc4989385498aec0bbe884dc2538502b82832e51b5cce3fe62
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive'
# !ls
# Out:
# /content/drive/My Drive
#  Data  'FeedBack Transformer'

# %%
import pandas as pd 
import pickle
import string
from string import digits
import re

# %%
def pre_processing(text):
    text = re.sub(r'[^\w\s]', '', str(text)) 
    remove_digits = str.maketrans('', '', digits) 
    text = text.translate(remove_digits)
    text = text.lower() 
    text = text.strip()   
    text = text.replace('  ',' ')  
    text = text.replace('   ',' ')

    return text

# %%
from tokenizers import ByteLevelBPETokenizer
from tokenizers.processors import BertProcessing

# %%
path = 'Data/Poem/train_dataset_24_03.txt'

tokenizer = ByteLevelBPETokenizer() 

tokenizer.train(files=path, vocab_size=52_000, min_frequency=2, special_tokens=[
    "<s>",
    "<pad>",
    "</s>",
    "<unk>",
    "<mask>",
])

# %%
# !mkdir Tokenizer_24_03
tokenizer.save_model("Tokenizer_24_03")
# Out:
# ['Tokenizer_24_03/vocab.json', 'Tokenizer_24_03/merges.txt']

# %%
from transformers import RobertaTokenizerFast

tokenizer = RobertaTokenizerFast.from_pretrained("./Tokenizer_24_03", max_len=512)

# %%
tokenizer.vocab_size
# Out:
# 11982
